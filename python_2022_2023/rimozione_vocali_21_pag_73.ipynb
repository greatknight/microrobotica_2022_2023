# %%
string = input("Inserisci una frase: ")

s = [i for i in string if i != "a" and i != "e" and i != "i" and i != "o" and i != "u" and i != "A" and i != "E" and i != "I" and i != "O" and i != "U"]
sFin = "".join(s)
print(sFin)
# Out:
# Inserisci una frase: buonasera popolo di striscia
# bnsr ppl d strsc

# %%
string = input("Inserisci una frase: ")
vocale = ["a", "e", "i", "o", "u", "A", "E", "I", "O", "U"]
lista = [lettera for lettera in string if(lettera not in vocale)]
s = "".join(lista)
print(s)
# Out:
# Inserisci una frase: BuonaseraaaaAAAAAAAAA
# Bnsr

# %%
var_lettura = open("sei_personaggi_in_cerca_dautore_Luigi_Pirandello.txt", "r")
righe = var_lettura.readlines()
var_lettura.close()

dic={}
y = 0

for elemento in righe:
    parole = elemento[:-1].split(" ")
    for i in parole:
        par = i[:-1].split(" ")
        dic[i] = y
        y = y + 1
        
print(dic)
# Out:
# {'ï»¿Sei': 0, 'personaggi': 17641, 'in': 21146, 'cerca': 2490, "d'autore": 4, '': 21026, 'di': 21169, 'Luigi': 8, 'Pirandello': 556, 'I': 18307, 'PERSONAGGI': 17, 'DELLA': 65, 'COMMEDIA': 19, 'DA': 20, 'FARE': 21, 'Il': 21055, 'padre': 20863, 'La': 20807, 'madre': 20689, 'figliastra': 18962, 'figlio': 20592, 'giovinetto': 43, 'bambina': 19316, '(questi': 50, 'ultimi': 3119, 'due': 18814, 'non': 20446, 'parlano)': 54, '(Poi,': 57, 'evocata)': 58, 'Madama': 15325, 'Pace': 12605, 'GLI': 63, 'ATTORI': 64, 'COMPAGNIA': 66, 'direttore-capocomico': 72, 'prima': 21088, 'attrice': 20809, 'primo': 21133, 'attore': 20827, 'seconda': 195, 'donna': 15479, "L'attrice": 13147, 'giovane': 13148, "L'attor": 19900, 'Altri': 20853, 'attori': 20854, 'e': 21180, 'attrici': 11341, 'direttore': 9683, 'scena': 20147, 'suggeritore': 1471, 'trovarobe': 115, 'macchinista': 360, 'segretario': 123, 'del': 21112, 'capocomico': 20921, "L'uscere": 2407, 'teatro': 21001, 'Apparatori': 16236, 'servi': 135, 'Di': 14187, 'giorno,': 14093, 'su': 19359, 'un': 21137, 'palcoscenico': 21075, 'prosa.': 150, 'N.B.': 153, 'commedia': 19961, 'ha': 20459, 'atti': 13061, 'nÃ©': 17545, 'scene.': 160, 'rappresentazione': 15110, 'sarÃ\xa0': 20741, 'interrotta': 9312, 'una': 21166, 'volta,': 17251, 'senza': 20432, 'che': 21126, 'il': 21158, 'sipario': 16229, "s'abbassi;": 172, 'allorchÃ©': 6971, 'Direttore': 9692, 'Capocomico': 20765, 'capo': 20744, 'dei': 21047, 'si': 21163, 'ritireranno': 183, 'per': 21153, 'concertar': 185, 'lo': 20575, 'scenario': 187, 'gli': 21141, 'sgombreranno': 9287, 'palcoscenico;': 19041, 'isbaglio': 199, 'Macchinista': 16141, 'butterÃ\xa0': 16142, 'giÃ¹': 21152, 'sipario.': 205, 'Troveranno': 208, 'spettatori,': 210, 'entrando': 211, 'nella': 21006, 'sala': 20913, 'teatro,': 18050, 'alzato': 216, 'sipario,': 16145, "com'Ã¨": 17234, 'quinte': 226, 'scena,': 13687, 'quasi': 19182, 'al': 20896, 'bujo': 231, 'vuoto,': 7377, 'perchÃ©': 20609, 'abbiano': 235, 'fin': 18946, 'da': 21122, 'principio': 16424, "l'impressione": 13753, "d'uno": 240, 'spettacolo': 15573, 'preparato.': 243, 'Due': 18405, 'scalette,': 247, 'a': 21139, 'destra': 328, "l'altra": 18233, 'sinistra,': 21123, 'metteranno': 1679, 'comunicazione': 257, 'con': 21095, 'la': 21192, 'sala.': 2434, 'Sul': 19389, 'cupolino': 13770, 'suggeritore,': 268, 'messo': 17598, 'parte,': 19911, 'canto': 16375, 'alla': 20289, 'buca.': 275, "Dall'altra": 278, 'sul': 21132, 'davanti,': 12469, 'tavolino': 9585, 'poltrona': 286, 'spalliera': 288, 'voltata': 289, 'verso': 21128, 'pubblico,': 1812, 'Direttore-Capocomico.': 295, 'tavolini,': 298, 'uno': 21033, 'piÃ¹': 21007, 'grande,': 19487, 'piccolo,': 9602, 'parecchie': 306, 'sedie': 307, 'attorno,': 3047, 'messi': 1894, 'lÃ¬': 21115, 'davanti': 20596, 'averli': 16864, 'pronti,': 315, 'bisogno,': 6564, 'prova.': 20971, 'Altre': 322, 'sedie,': 323, 'qua': 20368, 'lÃ¬:': 326, 'Attori;': 334, 'pianoforte': 690, 'fondo,': 20657, 'lato,': 11470, 'nascosto.': 344, 'Spenti': 9372, 'i': 21173, 'lumi': 9374, 'sala,': 21179, 'vedrÃ\xa0': 18484, 'entrare': 19598, 'dalla': 21178, 'porta': 13531, 'camiciotto': 362, 'turchino': 363, 'sacca': 365, 'appesa': 366, 'cintola;': 368, 'prendere': 19323, 'angolo': 372, 'fondo': 13670, 'alcuni': 20471, 'assi': 512, "d'attrezzatura;": 377, 'disporli': 378, 'mettersi': 17785, 'ginocchio': 384, 'inchiodarli.': 386, 'Alle': 16135, 'martellate': 388, 'accorrerÃ\xa0': 11531, 'camerini': 393, 'scena.': 20117, 'Oh!': 404, 'Che': 20961, 'fai?': 406, 'macchinista.': 9402, 'faccio?': 9632, 'Inchiodo.': 413, 'A': 20972, "quest'ora?": 421, 'GuarderÃ\xa0': 20955, "l'orologio.": 20956, 'Sono': 8730, 'giÃ\xa0': 19444, 'le': 21161, 'dieci': 956, 'mezzo.': 6190, 'momenti': 435, 'qui': 15919, 'Ma': 20869, 'dico,': 18756, 'dovrÃ²': 449, 'avere': 450, "anch'io": 17840, 'mio': 18280, 'tempo': 6818, 'lavorare!': 3270, "L'avrai,": 463, 'ma': 20398, 'ora.': 466, 'E': 20977, 'quando?': 472, 'Quando': 17678, "l'ora": 483, 'della': 21085, 'Su,': 14694, 'su,':  ...
